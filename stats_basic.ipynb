# %% [markdown]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales
#
# ans:-  Qualitative Data (Categorical Data):
# Qualitative data describes qualities or characteristics. It is non-numeric and used to categorize or label variables.
#
# Examples:
#
# Eye color (blue, brown, green)
#
# Subtypes of Qualitative Data:
#
# Nominal Scale:
#
# Categories with no logical order.
#
# Examples: Gender (male, female), Blood type (A, B, AB, O)
#
# Ordinal Scale:
#
# Categories with a meaningful order, but intervals between them are not consistent.
#
# Examples: Education level (high school, bachelor's, master's, PhD), Customer satisfaction (unsatisfied, neutral, satisfied)
#
# Quantitative Data (Numerical Data):
# Quantitative data represents measurable quantities. It is numeric and can be used in mathematical calculations.
#
# Examples:
#
# Height (in cm), Age (in years), Temperature.
#
# ubtypes of Quantitative Data:
#
# Interval Scale:
#
# Numeric scale with equal intervals but no true zero point.
#
# Examples: Temperature in Celsius or Fahrenheit, Dates on a calendar
#
# Ratio Scale:
#
# Numeric scale with equal intervals and a meaningful zero point, allowing for statements about how many times greater one value is than another.
#
# Examples: Weight, height, age, income, distance

# %% [markdown]
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate.
#
# ans:-Measures of central tendency are statistical values that describe the center or typical value of a dataset. The three main measures are:
#
# 1. Mean (Average)
# Definition:
# The mean is the sum of all values divided by the number of values.
#
# Formula:
#
# Mean
# =summation(x)/n
#
# Example:
# Test scores: 70, 80, 90
# Mean = (70 + 80 + 90) / 3 = 80
#
# When to Use:
#
# Data is quantitative
#
# Distribution is symmetric (no extreme outliers)
#
# 2. Median
# Definition:
# The median is the middle value when the data is ordered. If the dataset has an even number of values, it is the average of the two middle numbers.
#
# Example:
# Income data: $30k, $35k, $40k, $500k
# Ordered: 30k, 35k, 40k, 500k → Median = (35k + 40k)/2 = $37.5k
#
# When to Use:
#
# Data is quantitative or ordinal
#
# There are outliers or skewed distributions
#
# 3. Mode
# Definition:
# The mode is the value that appears most frequently in the dataset.
#
# Example:
# Shoe sizes: 8, 9, 9, 10, 11
# Mode = 9
#
# When to Use:
#
# Data is categorical or discrete
#
# You need to identify the most common item or value

# %% [markdown]
#  3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
#  ans:-Dispersion refers to the extent to which data values vary or spread around a central value.
#
# *If dispersion is low, data points are closely clustered. If it's high, values are spread out widely.
#
# variance:-Variance measures the average squared distance of each data point from the mean.
#
# standard deviation:-Standard deviation is the square root of the variance. It measures the average distance of each data point from the mean in the original units of the data.

# %% [markdown]
# 4.What is a box plot, and what can it tell you about the distribution of data?
#
# A box plot is a graphical representation of a dataset’s distribution, based on five summary statistics:
#
# Minimum – smallest data value (excluding outliers)
#
# First Quartile (Q1) – 25th percentile
#
# Median (Q2) – 50th percentile
#
# Third Quartile (Q3) – 75th percentile
#
# Maximum – largest data value (excluding outliers)

# %% [markdown]
#  5. Discuss the role of random sampling in making inferences about populations.
#
#  ans:-Random sampling is a method of selecting a subset (sample) from a larger group (population) in such a way that every member has an equal chance of being selected. This process is fundamental to making valid and reliable statistical inferences about the whole population.

# %% [markdown]
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#
# ans:-Skewness is a measure of the asymmetry of a probability distribution or dataset around its mean. It helps indicate whether the data values are balanced or lopsided.
#
# Types of Skewness
# 🔹 1. Symmetrical Distribution (Zero Skewness)
# Mean ≈ Median ≈ Mode
#
# The left and right sides of the distribution are mirror images.
#
# Example: Normal distribution (bell curve)
#
# 🔸 2. Positive Skew (Right-Skewed)
# Tail is longer on the right side
#
# Mean > Median > Mode
#
# Most data values are clustered on the left.
#
# Example: Income distribution (a few people earn much more than most)
#
# 🔹 3. Negative Skew (Left-Skewed)
# Tail is longer on the left side
#
# Mean < Median < Mode
#
# Most data values are clustered on the right.
#
# Example: Age at retirement (most retire in 60s, few much earlier)

# %% [markdown]
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#
# ans:-The interquartile range (IQR) is a measure of statistical dispersion, which represents the middle 50% of a dataset. It is calculated as the difference between the third quartile (Q3) and the first quartile (Q1):
#
# IQR=Q3−Q1
# Q1 (25th percentile): 25% of data falls below this value
#
# Q3 (75th percentile): 75% of data falls below this value
#
# Outliers are values that fall significantly outside the typical range of the data. The IQR method defines outliers as:
#
# Lower outlier: Any value less than
# Q1−1.5×IQR
#
# Upper outlier: Any value greater than
# Q3+1.5×IQR

# %% [markdown]
#  8. Discuss the conditions under which the binomial distribution is used.
#
#  ans:-The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes.
#
#   Conditions for Using the Binomial Distribution:-
#   *Fixed Number of Trials (n)
#
# The experiment is repeated a set number of times.
#
# *Only Two Outcomes Per Trial
#
# Each trial results in a success or failure (binary outcome).
#
# Example: win/lose, yes/no, defective/not defective
#
# *Constant Probability of Success (p)
#
# The probability of success stays the same for each trial.
#
# *Independent Trials
#
# The outcome of one trial does not affect the outcome of another.

# %% [markdown]
#  9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).

# %% [markdown]
# The normal distribution is a continuous, bell-shaped probability distribution that is symmetric about the mean.
#
# properties:
# Symmetrical: The left and right sides are mirror images.
#
# Mean = Median = Mode
#
# Bell-shaped curve
#
#  Empirical Rule (68-95-99.7 Rule)
# The Empirical Rule describes how data is distributed in a normal distribution:
#
# Range	% of Data Included
# μ ± 1σ (one standard deviation)	~68%
# μ ± 2σ (two standard deviations)	~95%
# μ ± 3σ (three standard deviations)	~99.7%

# %% [markdown]
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#
# Suppose a call center receives an average of 6 calls per hour. You want to calculate the probability that the center will receive exactly 4 calls in one hour.
#
# P(X=k)= e^-lamda *lamda^k/k(factorial)
#
# P(X=4)=e^-6*6^4/24=0.134
#
# ​

# %% [markdown]
#  11. Explain what a random variable is and differentiate between discrete and continuous random variables.

# %% [markdown]
# ans:-A random variable is a numerical value assigned to the outcomes of a random experiment.
#
# Discrete Random Variable:-
# Takes on a countable number of distinct values
#
# Often represents outcomes of counting processes (e.g., number of students, number of goals)
#
#
#  Continuous Random Variable
# Takes on any value within a range or interval
#
# Usually represents measurements (e.g., weight, height, time)

# %% [markdown]
#  12. Provide an example dataset, calculate both covariance and correlation, and interpret the results

# %% [markdown]
# | Student | Hours Studied (X) | Exam Score (Y) |
# | ------- | ----------------- | -------------- |
# | A       | 2                 | 65             |
# | B       | 4                 | 70             |
# | C       | 6                 | 75             |
# | D       | 8                 | 85             |
# | E       | 10                | 95             |
#
#
# Calculate the Means
# 𝑋(bar)=6
# y(bar)=78
#
# Cov(X,Y)= 37.5
# r=0.985
#
# Covariance = 37.5: Positive covariance means that as hours studied increases, exam scores tend to increase too.
#
# Correlation ≈ 0.985: Very strong positive linear relationship — studying more hours is strongly associated with higher exam scores.
